# %% [markdown]
# <a href="https://colab.research.google.com/github/Yeray18/harry-potter/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# hola esto es un comentario
"""esto es un comentario

multilinea
"""

producto="bicicleta";  # esto esuna variable
print("alvaro tiene una "+producto)
print(f"alvaro tiene una {producto}")

pelis=["titanic","star wars "]
print (pelis[1])
for i in pelis:
  print(i)
# Out:
# alvaro tiene una bicicleta
# alvaro tiene una bicicleta
# star wars
# titanic
# star wars

# %%
alumnos =["nadine","ruben","sergio","alvaro","conce","yeray"]

for i in alumnos:
  print(i)

alumnosinfo=[
    # 0nombre, 1apellido, 2nacimiento,  3gen, 4ciudad,  5telefono
    ["yeray",  "junio",   "2003",       "m", "xixón",   111111], #1
    ["ruben", "junio",    "1972",       "m", "xixón",   222222],
    ["sergio", "junio",   "1962",       "m", "xixón",   333333],
    ["alvaro", "junio",   "1975",       "m", "xixón",   444444],
    ["conce", "junio",    "1975",       "f", "xixón",   555555],
    ["nadir", "junio",    "1975",       "f", "xixón",   666666]
]

# Example of how to access and print information from alumnosinfo
for person in alumnosinfo:
    print(f"El telefono de {person[0]} es {person[5]}")

    print(f"nombre:   {person[0]} es {person[0]}")
# Out:
# nadine
# ruben
# sergio
# alvaro
# conce
# yeray
# El telefono de yeray es 111111
# nombre:   yeray es yeray
# El telefono de ruben es 222222
# nombre:   ruben es ruben
# El telefono de sergio es 333333
# nombre:   sergio es sergio
# El telefono de alvaro es 444444
# nombre:   alvaro es alvaro
# El telefono de conce es 555555
# nombre:   conce es conce
# El telefono de nadir es 666666
# nombre:   nadir es nadir
